# %% [markdown]
# # Example Notebook

# %% [markdown]
# # example notebook under subdirectory
# intro
# ## subsection
# content:
# example to hide code blocks

# %%
author="test_user"

# %%
print(f"Auther: {author}")

# %%
## Import libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
## Create some data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# %%
## Plot the data
for i in range(3):
    plt.figure(figsize=(8, 4))
    plt.plot(x, y, label='sin(x)')
    plt.title(f"Sine Wave Example {i+1}")
    plt.xlabel("x")
    plt.ylabel("sin(x)")
    plt.legend()
    plt.show()

# %% [markdown]
# ## example to link external figures
# ### Determine the repository where you want to activate Github Pages
# ![](https://ns2345k.web.sigma2.no/datalake/olivie/wp1/globalmean_BC_act.png)
